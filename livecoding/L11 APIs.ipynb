# %%
import pandas as pd
import numpy as np

# read_html returns a list of dataframes, each element is a table on the web
all_tables = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
len(all_tables)

constituents_table = all_tables[0]
constituents_table # drawback: won't save links
# Out:
#     Symbol                Security SEC filings             GICS Sector  \
# 0      MMM              3M Company     reports             Industrials
# 1      ABT     Abbott Laboratories     reports             Health Care
# 2     ABBV             AbbVie Inc.     reports             Health Care
# 3     ABMD             ABIOMED Inc     reports             Health Care
# 4      ACN           Accenture plc     reports  Information Technology
# ..     ...                     ...         ...                     ...
# 500    YUM         Yum! Brands Inc     reports  Consumer Discretionary
# 501   ZBRA      Zebra Technologies     reports  Information Technology
# 502    ZBH  Zimmer Biomet Holdings     reports             Health Care
# 503   ZION           Zions Bancorp     reports              Financials
# 504    ZTS                  Zoetis     reports             Health Care
#
#                       GICS Sub Industry     Headquarters Location  \
# ...

# %% [markdown]
# ## First API

# %%
import requests
base_url   = 'http://chroniclingamerica.loc.gov/search/pages/results/'
parameters = '?andtext=lynching&format=json'

type(r)
search_json = r.json()
url = base_url + parameters
print(url)  # manually opening URLs is a must

# open page and convert to df
r = requests.get(base_url + parameters)
r.status_code # check if it worked
pd.DataFrame(search_json['items'])
# Out:
# http://chroniclingamerica.loc.gov/search/pages/results/?andtext=lynching&format=json
#     sequence         county edition                           frequency  \
# 0          1        [Wayne]    None                              Weekly
# 1          4  [Cook County]    None  Daily (except Sunday and holidays)
# 2          4        [Hinds]    None                              Weekly
# 3         34         [None]    None                               Daily
# 4          4         [King]    None                              Weekly
# 5         12  [Cook County]    None  Daily (except Sunday and holidays)
# 6        123         [None]    None                               Daily
# 7          2     [Newberry]    None                              Weekly
# 8          2       [Marion]    None               Daily (except Sunday)
# 9         26     [Hartford]    None                 Daily (except Sun.)
# 10         4  [Cook County]    None  Daily (except Sunday and holidays)
# ...

# %%
type(r) # a response object
search_json = r.json()
type(search_json) # a dictionary...dict['key'] --> value (which can be any object)
search_json.keys() # what's in the dict?
search_json['totalItems']
search_json['startIndex']
type(search_json['items']) # list
first_item = search_json['items'][0] # first item is a dict
first_item.keys()
first_item['title']

# can convert JSON to dataframe
pd.DataFrame(search_json['items'])
# Out:
#     sequence         county edition                           frequency  \
# 0          1        [Wayne]    None                              Weekly
# 1          4  [Cook County]    None  Daily (except Sunday and holidays)
# 2          4        [Hinds]    None                              Weekly
# 3         34         [None]    None                               Daily
# 4          4         [King]    None                              Weekly
# 5         12  [Cook County]    None  Daily (except Sunday and holidays)
# 6        123         [None]    None                               Daily
# 7          2     [Newberry]    None                              Weekly
# 8          2       [Marion]    None               Daily (except Sunday)
# 9         26     [Hartford]    None                 Daily (except Sun.)
# 10         4  [Cook County]    None  Daily (except Sunday and holidays)
# 11         5         [None]    None                               Daily
# ...

# %%
# Class Activity
# run your own search (a different crime), and store the input in a dataframe

import requests
base_url   = 'http://chroniclingamerica.loc.gov/search/pages/results/'
parameters = '?andtext=firing+squad&format=json'

url = base_url + parameters
print(url)  # manually opening URLs is a must

# open page and convert to df
r = requests.get(base_url + parameters)
r.status_code # check if it worked
pd.DataFrame(search_json['items'])
r.json()['totalItems']
# Out:
# http://chroniclingamerica.loc.gov/search/pages/results/?andtext=firing+squad&format=json
# 324539

# %%
url = 'https://api.exchangeratesapi.io/latest?base=NOK'

r = requests.get(url)
r.status_code # check if it worked
currencyx = r.json()
pd.DataFrame(currencyx).describe()
# Out:
#              rates
# count    33.000000
# mean     52.535893
# std     264.815446
# min       0.077134
# 25%       0.172899
# 50%       0.673014
# 75%       3.170141
# max    1523.107728

# %%
url = 'https://api.exchangeratesapi.io/latest?base=EUR'

r = requests.get(url)
r.status_code # check if it worked
currencyx = r.json()
pd.DataFrame(currencyx)
# Out:
#            rates base        date
# AUD      1.71390  EUR  2020-04-14
# BGN      1.95580  EUR  2020-04-14
# BRL      5.65850  EUR  2020-04-14
# CAD      1.52570  EUR  2020-04-14
# CHF      1.05430  EUR  2020-04-14
# CNY      7.73660  EUR  2020-04-14
# CZK     26.86400  EUR  2020-04-14
# DKK      7.46230  EUR  2020-04-14
# GBP      0.87253  EUR  2020-04-14
# HKD      8.49750  EUR  2020-04-14
# HRK      7.61300  EUR  2020-04-14
# HUF    350.70000  EUR  2020-04-14
# IDR  17229.09000  EUR  2020-04-14
# ILS      3.92800  EUR  2020-04-14
# INR     83.49400  EUR  2020-04-14
# ISK    155.90000  EUR  2020-04-14
# JPY    117.66000  EUR  2020-04-14
# KRW   1332.53000  EUR  2020-04-14
# MXN     25.84850  EUR  2020-04-14
# MYR      4.75080  EUR  2020-04-14
# NOK     11.31180  EUR  2020-04-14
# NZD      1.80080  EUR  2020-04-14
# PHP     55.45300  EUR  2020-04-14
# PLN      4.54730  EUR  2020-04-14
# RON      4.83430  EUR  2020-04-14
# RUB     80.39230  EUR  2020-04-14
# ...

# %%
url = 'https://api.exchangeratesapi.io/2018-01-02?base=EUR&symbols=JPY'

r = requests.get(url)
r.status_code # check if it worked
currencyx = r.json()
pd.DataFrame(currencyx)
# Out:
#       rates base        date
# JPY  135.35  EUR  2018-01-02

# %%
url = 'https://api.exchangeratesapi.io/history?start_at=2018-01-01&end_at=2018-09-01'
params = ('base':'EUR','symbols':'JPY')
r = requests.get(url,params=params)
df = pd.DataFrame(r.json())
# Out:
#   File "<ipython-input-12-228657496af2>", line 2
#     params = ('base':'EUR','symbols':'JPY')
#                     ^
# SyntaxError: invalid syntax

# %%
url = 'https://api.exchangeratesapi.io/history?''
params = ('base':'EUR','symbols':'JPY','start_at':)
# Out:
#   File "<ipython-input-3-30149e440f07>", line 1
#     url = 'https://api.exchangeratesapi.io/history?''
#                                                      ^
# SyntaxError: EOL while scanning string literal
